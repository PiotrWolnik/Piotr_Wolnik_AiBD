# %%
import sqlalchemy 
from sqlalchemy import create_engine

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"

db = create_engine(db_string)

connection_sqlalchemy = db.connect()

result_set = db.execute("SELECT * FROM city")  
for r in result_set:  
    print(r)
# Out:
# (1, 'A Corua (La Corua)', 87, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (2, 'Abha', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (3, 'Abu Dhabi', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (4, 'Acua', 60, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (5, 'Adana', 97, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (6, 'Addis Abeba', 31, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (7, 'Aden', 107, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (8, 'Adoni', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (9, 'Ahmadnagar', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (10, 'Akishima', 50, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (11, 'Akron', 103, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (12, 'al-Ayn', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (13, 'al-Hawiya', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (14, 'al-Manama', 11, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (15, 'al-Qadarif', 89, datetime.datetime(2006, 2, 15, 9, 45, 25))
# ...

# %%
import psycopg2 as pg
import pandas as pd

# Zadanie 1

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')

df = pd.read_sql('select * from category',con=connection)
print(df)
# Out:
#     category_id         name         last_update
# 0             1       Action 2006-02-15 09:46:27
# 1             2    Animation 2006-02-15 09:46:27
# 2             3     Children 2006-02-15 09:46:27
# 3             4     Classics 2006-02-15 09:46:27
# 4             5       Comedy 2006-02-15 09:46:27
# 5             6  Documentary 2006-02-15 09:46:27
# 6             7        Drama 2006-02-15 09:46:27
# 7             8       Family 2006-02-15 09:46:27
# 8             9      Foreign 2006-02-15 09:46:27
# 9            10        Games 2006-02-15 09:46:27
# 10           11       Horror 2006-02-15 09:46:27
# 11           12        Music 2006-02-15 09:46:27
# 12           13          New 2006-02-15 09:46:27
# 13           14       Sci-Fi 2006-02-15 09:46:27
# 14           15       Sports 2006-02-15 09:46:27
# 15           16       Travel 2006-02-15 09:46:27
# ...

# %%
# Zadanie 2
df = pd.read_sql('select * from category order by name asc',con=connection)
print(df)
# Out:
#     category_id         name         last_update
# 0             1       Action 2006-02-15 09:46:27
# 1             2    Animation 2006-02-15 09:46:27
# 2             3     Children 2006-02-15 09:46:27
# 3             4     Classics 2006-02-15 09:46:27
# 4             5       Comedy 2006-02-15 09:46:27
# 5             6  Documentary 2006-02-15 09:46:27
# 6             7        Drama 2006-02-15 09:46:27
# 7             8       Family 2006-02-15 09:46:27
# 8             9      Foreign 2006-02-15 09:46:27
# 9            10        Games 2006-02-15 09:46:27
# 10           11       Horror 2006-02-15 09:46:27
# 11           12        Music 2006-02-15 09:46:27
# 12           13          New 2006-02-15 09:46:27
# 13           14       Sci-Fi 2006-02-15 09:46:27
# 14           15       Sports 2006-02-15 09:46:27
# 15           16       Travel 2006-02-15 09:46:27
# ...

# %%
# Zadanie 3
df = pd.read_sql('select title, release_year from film',con=connection)
df

youngest = pd.read_sql_query('select release_year, title from film order by release_year limit 1',con=connection)
oldest = pd.read_sql_query('select release_year, title from film order by release_year desc limit 1',con=connection)
# Wniosek: wszystkie filmy sa z tego samego roku, a wiec zarowno najmlodszy jak i najstarszy film sa z 2006 roku

youngest
oldest
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    release_year            title
# 0          2006  Chamber Italian

# %%
# Zadanie 4
df = pd.read_sql_query("SELECT COUNT(*) rental_date FROM rental WHERE rental_date between %s and %s", con=connection, params=['2005-07-01', '2005-08-01'])
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    rental_date
# 0         6709

# %%
# Zadanie 5
df = pd.read_sql_query("SELECT COUNT(*) rental_date FROM rental WHERE rental_date between %s and %s", con=connection, params=['2010-01-01', '2011-02-01'])
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    rental_date
# 0            0

# %%
# Zadanie 6
df = pd.read_sql("select max(amount) from payment", con=connection)
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      max
# 0  11.99

# %%
# Zadanie 7
df = pd.read_sql_query("""SELECT * FROM customer 
LEFT JOIN address ON customer.address_id = address.address_id 
LEFT JOIN city ON address.city_id = city.city_id 
LEFT JOIN country ON city.country_id = country.country_id 
WHERE country = %s OR country = %s OR country=%s""", 
con=connection, params=["Poland", "Nigeria", "Bangladesh"])
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     customer_id  store_id first_name  last_name  \
# 0           284         1      Sonia    Gregory
# 1           318         1      Brian      Wyman
# 2           572         1     Sidney   Burleson
# 3           409         2     Rodney    Moeller
# 4           332         1    Stephen     Qualls
# 5           286         1      Velma      Lucas
# 6            80         1    Marilyn       Ross
# 7           198         2      Elsie     Kelley
# 8           103         1     Gladys   Hamilton
# 9           329         2      Frank   Waggoner
# 10          128         1   Marjorie     Tucker
# 11           18         2      Carol     Garcia
# ...

# %%
# Zadanie 8
df = pd.read_sql_query("""
SELECT country.country from staff
LEFT JOIN address ON address.address_id = staff.address_id
LEFT JOIN city ON city.city_id = address.city_id
LEFT JOIN country ON country.country_id = city.country_id
""", con=connection)
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      country
# 0     Canada
# 1  Australia

# %%
# Zadanie 9
df = pd.read_sql_query("""
SELECT count(country.country) from staff
LEFT JOIN address ON address.address_id = staff.address_id
LEFT JOIN city ON city.city_id = address.city_id
LEFT JOIN country ON country.country_id = city.country_id
WHERE country = %s OR country = %s
""",
con=connection, params=["Argentina", "Spain"])
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    count
# 0      0

# %%
# Zadanie 10
df = pd.read_sql_query("""
SELECT DISTINCT category.name from category
LEFT JOIN film_category ON film_category.category_id = category.category_id
LEFT JOIN film ON film.film_id = film_category.film_id
LEFT JOIN inventory ON inventory.film_id = film.film_id
LEFT JOIN rental ON rental.inventory_id = inventory.inventory_id
LEFT JOIN customer ON customer.customer_id = rental.customer_id
""",
con=connection)
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#            name
# 0        Sports
# 1      Classics
# 2           New
# 3        Family
# 4        Comedy
# 5     Animation
# 6        Travel
# 7         Music
# 8         Drama
# 9        Horror
# 10       Sci-Fi
# 11        Games
# 12  Documentary
# 13      Foreign
# 14       Action
# 15     Children

# %%
# Zadanie 11
df = pd.read_sql_query("""
SELECT DISTINCT category.name from category
LEFT JOIN film_category ON film_category.category_id = category.category_id
LEFT JOIN film ON film.film_id = film_category.film_id
LEFT JOIN inventory ON inventory.film_id = film.film_id
LEFT JOIN rental ON rental.inventory_id = inventory.inventory_id
LEFT JOIN customer ON customer.customer_id = rental.customer_id
LEFT JOIN address ON address.address_id = customer.customer_id
LEFT JOIN city ON city.city_id = address.city_id
LEFT JOIN country ON country.country_id = country.country_id
WHERE country = %s
""",
con=connection,
params=["United States"])
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#            name
# 0        Sports
# 1      Classics
# 2           New
# 3        Family
# 4        Comedy
# 5     Animation
# 6        Travel
# 7         Music
# 8         Drama
# 9        Horror
# 10       Sci-Fi
# 11        Games
# 12  Documentary
# 13      Foreign
# 14       Action
# 15     Children

# %%
# Zadanie 12
df = pd.read_sql_query("""
SELECT title from film
LEFT JOIN film_actor ON film_actor.film_id = film.film_id
LEFT JOIN actor ON actor.actor_id = film_actor.actor_id
WHERE (actor.first_name = %s AND actor.last_name = %s) 
    OR (actor.first_name = %s AND actor.last_name = %s)
    OR (actor.first_name = %s AND actor.last_name = %s)
""",
con=connection,
params=['Olympia', 'Pfeiffer', 'Julia',  'Zellweger', 'Ellen',  'Presley'])
df
# Out:
# /home/piotr/anaconda3/envs/piotrWolnikEnv/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                 title
# 0     Bilko Anonymous
# 1   Caribbean Liberty
# 2    Casper Dragonfly
# 3    Empire Malkovich
# 4       Floats Garden
# ..                ...
# 64       Outlaw Hanky
# 65    Panky Submarine
# 66   Rider Caddyshack
# 67          Won Dares
# 68      Wyoming Storm
#
# [69 rows x 1 columns]
